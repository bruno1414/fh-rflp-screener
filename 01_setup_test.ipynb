# %%
# Import the MspI restriction enzyme from Biopython.
# Import the MspI restriction enzyme from Biopython.
# Import the MspI restriction enzyme from Biopython for RFLP analysis.
from Bio.Restriction import MspI
# Import the Seq object from Biopython for handling biological sequences.
# Import the Seq object from Biopython for handling biological sequences.
# Import the Seq object from Biopython to handle biological sequences (DNA, RNA, protein).
from Bio.Seq import Seq

# Define a test DNA sequence.
# Define a test DNA sequence.
# Define a sample DNA sequence for testing restriction enzyme digestion.
test_seq = Seq("AATGCCGGTTAAGCCGGAATC")
# Perform in-silico digestion of the test sequence using MspI.
# Perform in-silico digestion of the test sequence using MspI.
# Simulate restriction enzyme digestion using MspI on the test sequence. `linear=True` indicates a linear DNA molecule.
cuts = MspI.catalyze(test_seq, linear=True)
# Print the identified cut positions.
# Print the identified cut positions.
# Output the 0-based indices where the MspI enzyme cuts the DNA sequence.
print(f"Cut positions: {cuts}")
# Print the total number of cuts.
# Print the total number of cuts.
# Display the total number of cleavage sites found by MspI.
print(f"Number of cuts: {len(cuts)}")
# Indicate completion of the setup and test phase.
# Indicate completion of the setup and test phase.
# Marker indicating the successful completion of the setup and initial testing phase.
print("Phase 1 complete!")
# Out:
# Cut positions: (Seq('AATGC'), Seq('CGGTTAAGC'), Seq('CGGAATC'))
# Number of cuts: 3
# Phase 1 complete!
